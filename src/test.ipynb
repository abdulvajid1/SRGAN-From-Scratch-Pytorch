# %% [markdown]
# print('hai')

# %%
from generator import Generator
# Out:
# /Users/abdulvajid/AI/PROJECTS/SRGAN-From-Scratch-Pytorch/.venv/lib/python3.9/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
print('hello world')
# Out:
# hello world

# %%
import album

# %%
sorted(list(Path('/workspace/src/checkpoints').glob("*.ckpt")), key=lambda p: int(p.stem.split("_")[-1]))[-1]
# Out:
# PosixPath('/workspace/src/checkpoints/ckpt_152.ckpt')

# %%
from pathlib import Path
for i in list(Path('/workspace/src/checkpoints').glob('*.ckpt')):
    print(int(i.stem.split('_')[-1])
# Out:
# 1
# 151
# 152
# 2
# 3

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch

props = torch.cuda.get_device_properties(0)
print(f"Name: {props.name}")
print(f"Multiprocessors (SMs): {props.multi_processor_count}")
print(f"Total CUDA Cores (approx): {props.multi_processor_count * 128}")
print(f"Compute capability: {props.major}.{props.minor}")
# Out:
# Name: NVIDIA GeForce RTX 5070
# Multiprocessors (SMs): 48
# Total CUDA Cores (approx): 6144
# Compute capability: 12.0

# %%
Generator()
# Out:
# Generator(
#   (generator): Sequential(
#     (0): InputLayer(
#       (conv_layer): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#       (prelu): PReLU(num_parameters=64)
#       (input_layer): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#         (1): PReLU(num_parameters=64)
#       )
#     )
#     (1): ResidualBlock(
#       (residual_blocks): Sequential(
#         (0): ResConvBlock(
#           (conv_block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): PReLU(num_parameters=64)
#             (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): PReLU(num_parameters=64)
#           )
#         )
# ...

# %%
import albumentations
